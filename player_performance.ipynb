# %%
from fetcher import get_player_info
from player_performance import get_player_points_per_gameweek, create_points_dataframe_with_gameweeks
import pandas as pd

# %%
x_gameweeks = 5  # Number of recent gameweeks to consider
current_gameweek = 6  # Replace with the current gameweek number

# Define the range of gameweeks
gameweeks = list(range(current_gameweek - x_gameweeks + 1, current_gameweek + 1))

# Get player information
players = get_player_info()

# Get player points for each gameweek
player_points_per_gw = {}
for gw in gameweeks:
    player_points_per_gw[gw] = get_player_points_per_gameweek(gw)

# Create and sort the DataFrame by total points across the gameweeks
sorted_points_df = create_points_dataframe_with_gameweeks(player_points_per_gw, players, gameweeks, min_to_return=5)

# Display the sorted DataFrame
sorted_points_df
# Out:
#      Player ID Player Name  Team ID  Team Name  Position  Points Per Game  \
# 205        182      Palmer        6    Chelsea         3             10.2
# 413        351     Haaland       13   Man City         4             10.8
# 388        327   Luis Díaz       12  Liverpool         3              8.8
# 389        328     M.Salah       12  Liverpool         3              9.8
# 203        180   N.Jackson        6    Chelsea         4              6.7
# ..         ...         ...      ...        ...       ...              ...
# 287        246      Harris        9     Fulham         3              0.0
# 285        244    Castagne        9     Fulham         2              0.0
# 283        242       Benda        9     Fulham         1              0.0
# 647        554     José Sá       20     Wolves         1              0.5
# 165        147     Webster        5   Brighton         2              0.0
#
#      Form  Selected By Percent  Now Cost  GW2 Points  GW3 Points  GW4 Points  \
# ...

# %%
# Batch Player from Price and Position
# Goalkeeper

gk_df = sorted_points_df[sorted_points_df['Position'] == 1]

price_brackets = [0, 45, 50, 60]
bracket_labels = ['Bracket 1', 'Bracket 2', 'Bracket 3']

gk_df['price_bracket'] = pd.cut(gk_df['Now Cost'], bins=price_brackets, labels=bracket_labels, include_lowest=True)
gk_df = gk_df.sort_values(['price_bracket', 'Number Returns'], ascending=[True, False])
df_top_3_per_bracket = gk_df.groupby('price_bracket').head(3)
df_top_3_per_bracket
# Out:
# /var/folders/g2/7dxps7694kb0wbjy_58dzs140000gn/T/ipykernel_34573/256794205.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gk_df['price_bracket'] = pd.cut(gk_df['Now Cost'], bins=price_brackets, labels=bracket_labels, include_lowest=True)
# /var/folders/g2/7dxps7694kb0wbjy_58dzs140000gn/T/ipykernel_34573/256794205.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_top_3_per_bracket = gk_df.groupby('price_bracket').head(3)
#      Player ID Player Name  Team ID       Team Name  Position  \
# ...

# %%
# Defender

def_df = sorted_points_df[sorted_points_df['Position'] == 2]

price_brackets = [0, 42, 47, 52, 75]
bracket_labels = ['Bracket 1', 'Bracket 2', 'Bracket 3', 'Bracket 4']

def_df['price_bracket'] = pd.cut(def_df['Now Cost'], bins=price_brackets, labels=bracket_labels, include_lowest=True)
def_df = def_df.sort_values(['price_bracket', 'Number Returns'], ascending=[True, False])
df_top_3_per_bracket = def_df.groupby('price_bracket').head(3)
df_top_3_per_bracket
# Out:
# /var/folders/g2/7dxps7694kb0wbjy_58dzs140000gn/T/ipykernel_34573/1107414829.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   def_df['price_bracket'] = pd.cut(def_df['Now Cost'], bins=price_brackets, labels=bracket_labels, include_lowest=True)
# /var/folders/g2/7dxps7694kb0wbjy_58dzs140000gn/T/ipykernel_34573/1107414829.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_top_3_per_bracket = def_df.groupby('price_bracket').head(3)
#      Player ID       Player Name  Team ID      Team Name  Position  \
# ...

# %%
# Midfielder

mid_df = sorted_points_df[sorted_points_df['Position'] == 3]

price_brackets = [0, 47, 57, 67, 77, 97, 130]
bracket_labels = ['Bracket 1', 'Bracket 2', 'Bracket 3', 'Bracket 4', 'Bracket 5', 'Bracket 6']

mid_df['price_bracket'] = pd.cut(mid_df['Now Cost'], bins=price_brackets, labels=bracket_labels, include_lowest=True)
mid_df = mid_df.sort_values(['price_bracket', 'Number Returns'], ascending=[True, False])
df_top_3_per_bracket = mid_df.groupby('price_bracket').head(3)
df_top_3_per_bracket
# Out:
# /var/folders/g2/7dxps7694kb0wbjy_58dzs140000gn/T/ipykernel_34573/1630460180.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mid_df['price_bracket'] = pd.cut(mid_df['Now Cost'], bins=price_brackets, labels=bracket_labels, include_lowest=True)
# /var/folders/g2/7dxps7694kb0wbjy_58dzs140000gn/T/ipykernel_34573/1630460180.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_top_3_per_bracket = mid_df.groupby('price_bracket').head(3)
#      Player ID  Player Name  Team ID    Team Name  Position  Points Per Game  \
# ...

# %%
# Forward

fwd_df = sorted_points_df[sorted_points_df['Position'] == 4]

price_brackets = [0, 47, 57, 67, 77, 160]
bracket_labels = ['Bracket 1', 'Bracket 2', 'Bracket 3', 'Bracket 4', 'Bracket 5']

fwd_df['price_bracket'] = pd.cut(fwd_df['Now Cost'], bins=price_brackets, labels=bracket_labels, include_lowest=True)
fwd_df = fwd_df.sort_values(['price_bracket', 'Number Returns'], ascending=[False, False])
df_top_3_per_bracket = fwd_df.groupby('price_bracket').head(3)
df_top_3_per_bracket
# Out:
# /var/folders/g2/7dxps7694kb0wbjy_58dzs140000gn/T/ipykernel_34573/3479961003.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fwd_df['price_bracket'] = pd.cut(fwd_df['Now Cost'], bins=price_brackets, labels=bracket_labels, include_lowest=True)
# /var/folders/g2/7dxps7694kb0wbjy_58dzs140000gn/T/ipykernel_34573/3479961003.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_top_3_per_bracket = fwd_df.groupby('price_bracket').head(3)
#      Player ID    Player Name  Team ID       Team Name  Position  \
# ...
