# %%
from ownership import create_ownership_dataframe, calculate_ownership
from fetcher import get_top_X_managers, get_player_info, get_teams_dict
from tqdm import tqdm

# %%
n = 10000

# %%
# top_1000_managers = get_top_X_managers(1000)
top_10000_managers = get_top_X_managers(n)
player_info = get_player_info()
teams_dict = get_teams_dict()

# %%
with open('top_manager.txt', 'w') as file:
    for number in top_10000_managers:
        file.write(f"{number}\n")

# %%
# Run Golang

# %%
with open("output.txt", "r") as file:
    # Initialize an empty dictionary
    my_dict = {}

    # Read the file line by line
    for line in file:
        # Strip the newline character and any leading/trailing spaces
        line = line.strip()

        # Split the line into key and value (assuming format "key: value")
        key, value = line.split(": ")
        keyInt = int(key)

        # Convert the value to an integer and add it to the dictionary
        my_dict[keyInt] = int(value)

    ownership_percentage = {player_id: (count / n) * 100 for player_id, count in my_dict.items()}
    sorted_ownership = sorted(ownership_percentage.items(), key=lambda item: item[1], reverse=True)

# %%
# sorted_ownership = calculate_ownership(top_1000_managers, 2, is_captain=False, is_play_only=False)
df = create_ownership_dataframe(sorted_ownership, player_info, teams_dict, 0)
df
# Out:
# 100%|██████████| 499/499 [00:00<00:00, 653028.92it/s]
#      Player ID    Player Name  Team ID    Team Name  Ownership  Position  \
# 0          351        Haaland       13     Man City      92.63         4
# 1          182         Palmer        6      Chelsea      80.94         3
# 2           54         Rogers        2  Aston Villa      62.09         3
# 3           19     Smith Rowe        9       Fulham      59.54         3
# 4          328        M.Salah       12    Liverpool      54.81         3
# ..         ...            ...      ...          ...        ...       ...
# 494        560           Neto        6      Chelsea       0.01         3
# 495        166  Dewsbury-Hall        6      Chelsea       0.01         3
# 496        320           Endo       12    Liverpool       0.01         3
# 497        165         Deivid        6      Chelsea       0.01         4
# 498        621     João Félix        6      Chelsea       0.01         3
#
# ...

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='delta', ascending=False)
df_delta = df_delta[df_delta['Position'] == 4]
df_delta = df_delta[df_delta['Form'] >= 4]
df_delta = df_delta[df_delta['delta'] >= 0]
df_delta[:10]
# Out:
#      Player ID Player Name  Team ID      Team Name  Ownership  Position  \
# 0          351     Haaland       13       Man City      92.63         4
# 7           58     Watkins        2    Aston Villa      42.28         4
# 30         447        Wood       16  Nott'm Forest      16.10         4
# 55         252        Raúl        9         Fulham       5.49         4
# 26         180   N.Jackson        6        Chelsea      17.72         4
# 142        232      Ndiaye        8        Everton       0.91         4
#
#      Points Per Game  Form  Selected By Percent  Now Cost  delta
# 0               10.8   8.0                 73.1     153.0  19.53
# 7                6.5  10.0                 29.0      91.0  13.28
# 30               5.2   4.0                 11.1      62.0   5.00
# 55               4.5   8.0                  4.0      55.0   1.49
# 26               6.7   7.0                 17.0      79.0   0.72
# 142              2.7   4.0                  0.8      54.0   0.11

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='delta', ascending=False)
df_delta = df_delta[df_delta['Position'] == 3]
df_delta = df_delta[df_delta['Form'] >= 4]
df_delta = df_delta[df_delta['delta'] >= 0]
df_delta[:10]
# Out:
#     Player ID Player Name  Team ID    Team Name  Ownership  Position  \
# 2          54      Rogers        2  Aston Villa      62.09         3
# 1         182      Palmer        6      Chelsea      80.94         3
# 3          19  Smith Rowe        9       Fulham      59.54         3
# 10         99      Mbeumo        4    Brentford      35.71         3
# 4         328     M.Salah       12    Liverpool      54.81         3
# 5         327   Luis Díaz       12    Liverpool      47.39         3
# 36        230      McNeil        8      Everton      10.11         3
# 65          9  Martinelli        1      Arsenal       4.23         3
#
#     Points Per Game  Form  Selected By Percent  Now Cost  delta
# 2               4.2   6.3                 19.4      52.0  42.69
# 1              10.2  10.5                 44.4     107.0  36.54
# 3               5.5   6.0                 29.8      58.0  29.74
# 10              7.2   6.3                 22.3      74.0  13.41
# ...

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='delta', ascending=False)
df_delta = df_delta[df_delta['Position'] == 2]
df_delta = df_delta[df_delta['Form'] >= 4]
df_delta = df_delta[df_delta['delta'] >= 0]
df_delta[:10]
# Out:
#     Player ID       Player Name  Team ID  Team Name  Ownership  Position  \
# 22        326            Konaté       12  Liverpool      20.09         2
# 12          3           Gabriel        1    Arsenal      31.11         2
# 9         311  Alexander-Arnold       12  Liverpool      36.42         2
#
#     Points Per Game  Form  Selected By Percent  Now Cost  delta
# 22              5.2   5.8                  9.5      52.0  10.59
# 12              6.2   7.7                 24.7      62.0   6.41
# 9               5.5   4.8                 32.1      71.0   4.32

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='delta', ascending=False)
df_delta = df_delta[df_delta['Position'] == 1]
df_delta = df_delta[df_delta['Form'] >= 4]
df_delta = df_delta[df_delta['delta'] >= 0]
df_delta[:10]
# Out:
#     Player ID Player Name  Team ID      Team Name  Ownership  Position  \
# 8         185     Sánchez        6        Chelsea      36.44         1
# 11         15        Raya        1        Arsenal      31.73         1
# 72        443        Sels       16  Nott'm Forest       3.28         1
#
#     Points Per Game  Form  Selected By Percent  Now Cost  delta
# 8               5.3   7.2                 11.4      47.0  25.04
# 11              5.7   4.7                 30.9      56.0   0.83
# 72              3.8   4.0                  2.9      45.0   0.38

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='Form', ascending=False)
df_delta = df_delta[df_delta['Position'] == 4]
df_delta = df_delta[df_delta['Form'] >= 5]
df_delta = df_delta[df_delta['delta'] <= 0]
df_delta[:10]
# Out:
# Empty DataFrame
# Columns: [Player ID, Player Name, Team ID, Team Name, Ownership, Position, Points Per Game, Form, Selected By Percent, Now Cost, delta]
# Index: []

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='Form', ascending=False)
df_delta = df_delta[df_delta['Position'] == 3]
df_delta = df_delta[df_delta['Form'] >= 5]
df_delta = df_delta[df_delta['delta'] <= 0]
df_delta[:10]
# Out:
#      Player ID Player Name  Team ID  Team Name  Ownership  Position  \
# 101        392      Barnes       15  Newcastle       1.73         3
# 194        298    Mavididi       11  Leicester       0.37         3
# 185        491     Johnson       18      Spurs       0.46         3
# 408        115      Baleba        5   Brighton       0.02         3
#
#      Points Per Game  Form  Selected By Percent  Now Cost  delta
# 101              5.8   7.2                  4.0      65.0  -2.27
# 194              3.7   6.3                  0.8      53.0  -0.43
# 185              4.8   6.0                  1.4      64.0  -0.94
# 408              3.8   5.3                  0.2      50.0  -0.18

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='Form', ascending=False)
df_delta = df_delta[df_delta['Position'] == 2]
df_delta = df_delta[df_delta['Form'] >= 5]
df_delta = df_delta[df_delta['delta'] <= 0]
df_delta[:10]
# Out:
#      Player ID Player Name  Team ID  Team Name  Ownership  Position  \
# 143        593     De Ligt       14    Man Utd       0.90         2
# 41         369       Dalot       14    Man Utd       8.13         2
# 259        295      Justin       11  Leicester       0.13         2
#
#      Points Per Game  Form  Selected By Percent  Now Cost  delta
# 143              4.0   5.5                  4.9      50.0  -4.00
# 41               4.8   5.2                  9.7      51.0  -1.57
# 259              3.2   5.0                  0.7      45.0  -0.57

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='Form', ascending=False)
df_delta = df_delta[df_delta['Position'] == 1]
df_delta = df_delta[df_delta['Form'] >= 5]
df_delta = df_delta[df_delta['delta'] <= 0]
df_delta[:10]
# Out:
#     Player ID Player Name  Team ID Team Name  Ownership  Position  \
# 71        383       Onana       14   Man Utd       3.32         1
#
#     Points Per Game  Form  Selected By Percent  Now Cost  delta
# 71              5.5   6.5                  5.9      50.0  -2.58
