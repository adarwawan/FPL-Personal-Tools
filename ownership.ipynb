# %%
from ownership import create_ownership_dataframe, calculate_ownership
from fetcher import get_top_X_managers, get_player_info, get_teams_dict
from tqdm import tqdm

# %%
n = 10000

# %%
# top_1000_managers = get_top_X_managers(1000)
top_10000_managers = get_top_X_managers(n)
player_info = get_player_info()
teams_dict = get_teams_dict()

# %%
with open('top_manager.txt', 'w') as file:
    for number in top_10000_managers:
        file.write(f"{number}\n")

# %%
# Run Golang

# %%
with open("output.txt", "r") as file:
    # Initialize an empty dictionary
    my_dict = {}

    # Read the file line by line
    for line in file:
        # Strip the newline character and any leading/trailing spaces
        line = line.strip()

        # Split the line into key and value (assuming format "key: value")
        key, value = line.split(": ")
        keyInt = int(key)

        # Convert the value to an integer and add it to the dictionary
        my_dict[keyInt] = int(value)

    ownership_percentage = {player_id: (count / n) * 100 for player_id, count in my_dict.items()}
    sorted_ownership = sorted(ownership_percentage.items(), key=lambda item: item[1], reverse=True)

# %%
# sorted_ownership = calculate_ownership(top_1000_managers, 2, is_captain=False, is_play_only=False)
df = create_ownership_dataframe(sorted_ownership, player_info, teams_dict, 0)
df
# Out:
# 100%|██████████| 540/540 [00:00<00:00, 417036.30it/s]
#      Player ID       Player Name  Team ID    Team Name  Ownership  Position  \
# 0          351           Haaland       13     Man City      97.47         4
# 1          327         Luis Díaz       12    Liverpool      69.40         3
# 2           19        Smith Rowe        9       Fulham      64.69         3
# 3          328           M.Salah       12    Liverpool      55.92         3
# 4          311  Alexander-Arnold       12    Liverpool      51.02         2
# ..         ...               ...      ...          ...        ...       ...
# 535        375           Højlund       14      Man Utd       0.01         4
# 536         93            Hickey        4    Brentford       0.01         2
# 537        382             Mount       14      Man Utd       0.01         3
# 538        452             Aribo       17  Southampton       0.01         3
# 539          5              Hein        1      Arsenal       0.01         1
#
#      Points Per Game  Form  Selected By Percent  Now Cost
# 0               12.6  13.0                 71.7     153.0
# 1               10.2  11.3                 31.0      79.0
# 2                6.0   5.7                 29.7      58.0
# 3                9.8   8.3                 45.5     128.0
# 4                6.4   6.0                 32.3      71.0
# ..               ...   ...                  ...       ...
# 535              1.0   0.3                  0.4      69.0
# 536              0.0   0.0                  0.0      44.0
# 537              1.5   0.0                  0.1      63.0
# 538              1.8   1.0                  0.1      50.0
# 539              0.0   0.0                  0.0      40.0
#
# [540 rows x 10 columns]

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='delta', ascending=False)
df_delta = df_delta[df_delta['Position'] == 4]
df_delta = df_delta[df_delta['Form'] >= 4]
df_delta = df_delta[df_delta['delta'] >= 0]
df_delta[:10]
# Out:
#     Player ID    Player Name  Team ID      Team Name  Ownership  Position  \
# 0         351        Haaland       13       Man City      97.47         4
# 25        447           Wood       16  Nott'm Forest      17.13         4
# 26        180      N.Jackson        6        Chelsea      16.31         4
# 56        220  Calvert-Lewin        8        Everton       5.65         4
# 13         58        Watkins        2    Aston Villa      29.02         4
# 74        110          Wissa        4      Brentford       3.75         4
#
#     Points Per Game  Form  Selected By Percent  Now Cost  delta
# 0              12.6  13.0                 71.7     153.0  25.77
# 25              5.8   6.3                  8.6      61.0   8.53
# 26              7.0   7.7                 11.9      77.0   4.41
# 56              4.8   6.7                  4.7      60.0   0.95
# 13              5.6   8.0                 28.8      90.0   0.22
# 74              7.0   5.0                  3.6      60.0   0.15

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='delta', ascending=False)
df_delta = df_delta[df_delta['Position'] == 3]
df_delta = df_delta[df_delta['Form'] >= 4]
df_delta = df_delta[df_delta['delta'] >= 0]
df_delta[:10]
# Out:
#      Player ID Player Name  Team ID    Team Name  Ownership  Position  \
# 1          327   Luis Díaz       12    Liverpool      69.40         3
# 2           19  Smith Rowe        9       Fulham      64.69         3
# 6           54      Rogers        2  Aston Villa      42.84         3
# 3          328     M.Salah       12    Liverpool      55.92         3
# 27          99      Mbeumo        4    Brentford      15.40         3
# 84         230      McNeil        8      Everton       3.18         3
# 77         392      Barnes       15    Newcastle       3.51         3
# 129        247       Iwobi        9       Fulham       1.21         3
#
#      Points Per Game  Form  Selected By Percent  Now Cost  delta
# 1               10.2  11.3                 31.0      79.0  38.40
# 2                6.0   5.7                 29.7      58.0  34.99
# 6                3.6   4.7                 17.4      52.0  25.44
# 3                9.8   8.3                 45.5     128.0  10.42
# 27               6.8   8.0                 14.9      72.0   0.50
# 84               4.8   6.7                  2.8      54.0   0.38
# 77               6.6   9.0                  3.2      65.0   0.31
# 129              4.4   4.0                  1.2      55.0   0.01

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='delta', ascending=False)
df_delta = df_delta[df_delta['Position'] == 2]
df_delta = df_delta[df_delta['Form'] >= 4]
df_delta = df_delta[df_delta['delta'] >= 0]
df_delta[:10]
# Out:
#      Player ID       Player Name  Team ID    Team Name  Ownership  Position  \
# 4          311  Alexander-Arnold       12    Liverpool      51.02         2
# 10           3           Gabriel        1      Arsenal      32.45         2
# 18          44             Konsa        2  Aston Villa      21.96         2
# 17         594          Mazraoui       14      Man Utd      22.20         2
# 29         369             Dalot       14      Man Utd      15.31         2
# 33          36             Digne        2  Aston Villa      11.55         2
# 40         326            Konaté       12    Liverpool       9.37         2
# 42         335         Robertson       12    Liverpool       8.79         2
# 83         162           Colwill        6      Chelsea       3.21         2
# 104        267             Davis       10      Ipswich       2.09         2
#
#      Points Per Game  Form  Selected By Percent  Now Cost  delta
# 4                6.4   6.0                 32.3      71.0  18.72
# 10               7.2   8.0                 19.0      61.0  13.45
# 18               3.0   4.0                 13.7      45.0   8.26
# 17               5.0   4.3                 16.0      46.0   6.20
# 29               5.8   7.0                  9.3      50.0   6.01
# 33               3.2   4.0                  8.0      46.0   3.55
# 40               4.8   5.3                  7.4      51.0   1.97
# 42               5.0   4.3                  7.6      60.0   1.19
# 83               3.2   4.7                  2.4      45.0   0.81
# 104              3.2   5.0                  2.0      45.0   0.09

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='delta', ascending=False)
df_delta = df_delta[df_delta['Position'] == 1]
df_delta = df_delta[df_delta['Form'] >= 4]
df_delta = df_delta[df_delta['delta'] >= 0]
df_delta[:10]
# Out:
#     Player ID Player Name  Team ID       Team Name  Ownership  Position  \
# 14        185     Sánchez        6         Chelsea      25.28         1
# 5          15        Raya        1         Arsenal      42.88         1
# 32        201   Henderson        7  Crystal Palace      13.59         1
# 93        443        Sels       16   Nott'm Forest       2.68         1
#
#     Points Per Game  Form  Selected By Percent  Now Cost  delta
# 14              6.0   9.0                  8.7      46.0  16.58
# 5               6.6   5.0                 31.8      56.0  11.08
# 32              3.4   4.7                 12.4      45.0   1.19
# 93              4.2   4.0                  2.5      45.0   0.18

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='Form', ascending=False)
df_delta = df_delta[df_delta['Position'] == 4]
df_delta = df_delta[df_delta['Form'] >= 5]
df_delta = df_delta[df_delta['delta'] <= 0]
df_delta[:10]
# Out:
#      Player ID Player Name  Team ID       Team Name  Ownership  Position  \
# 72          38       Duran        2     Aston Villa       3.88         4
# 107        207      Mateta        7  Crystal Palace       1.97         4
# 171        252        Raúl        9          Fulham       0.65         4
#
#      Points Per Game  Form  Selected By Percent  Now Cost  delta
# 72               5.0   6.0                  5.2      61.0  -1.32
# 107              3.8   5.3                  4.5      74.0  -2.53
# 171              3.6   5.3                  1.7      54.0  -1.05

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='Form', ascending=False)
df_delta = df_delta[df_delta['Position'] == 3]
df_delta = df_delta[df_delta['Form'] >= 5]
df_delta = df_delta[df_delta['delta'] <= 0]
df_delta[:10]
# Out:
#      Player ID Player Name  Team ID       Team Name  Ownership  Position  \
# 208        298    Mavididi       11       Leicester       0.37         3
# 9          182      Palmer        6         Chelsea      33.30         3
# 12          17        Saka        1         Arsenal      29.58         3
# 268        557   Mario Jr.       20          Wolves       0.16         3
# 23         199         Eze        7  Crystal Palace      17.70         3
# 81         239       Adama        9          Fulham       3.35         3
# 85         494    Maddison       18           Spurs       3.16         3
# 192        300       Ndidi       11       Leicester       0.49         3
# 49         503         Son       18           Spurs       7.08         3
#
#      Points Per Game  Form  Selected By Percent  Now Cost  delta
# 208              4.0   6.0                  0.5      53.0  -0.13
# 9                7.2   5.7                 39.6     106.0  -6.30
# 12               7.0   5.7                 30.6     100.0  -1.02
# 268              4.0   5.3                  0.4      50.0  -0.24
# 23               3.8   5.0                 22.7      69.0  -5.00
# 81               4.6   5.0                  3.9      51.0  -0.55
# 85               5.2   5.0                  4.5      75.0  -1.34
# 192              3.8   5.0                  0.6      50.0  -0.11
# 49               6.6   5.0                  8.7     100.0  -1.62

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='Form', ascending=False)
df_delta = df_delta[df_delta['Position'] == 2]
df_delta = df_delta[df_delta['Form'] >= 5]
df_delta = df_delta[df_delta['delta'] <= 0]
df_delta[:10]
# Out:
#      Player ID Player Name  Team ID Team Name  Ownership  Position  \
# 109        593     De Ligt       14   Man Utd       1.88         2
#
#      Points Per Game  Form  Selected By Percent  Now Cost  delta
# 109              4.6   7.0                  4.7      50.0  -2.82

# %%
df_delta = df
df_delta['delta'] = df_delta['Ownership'] - df_delta['Selected By Percent']
df_delta = df_delta.sort_values(by='Form', ascending=False)
df_delta = df_delta[df_delta['Position'] == 1]
df_delta = df_delta[df_delta['Form'] >= 5]
df_delta = df_delta[df_delta['delta'] <= 0]
df_delta[:10]
# Out:
#      Player ID Player Name  Team ID Team Name  Ownership  Position  \
# 61         383       Onana       14   Man Utd       5.36         1
# 189        568       Muric       10   Ipswich       0.52         1
#
#      Points Per Game  Form  Selected By Percent  Now Cost  delta
# 61               6.0   7.7                  5.7      50.0  -0.34
# 189              4.0   5.3                  0.8      44.0  -0.28
